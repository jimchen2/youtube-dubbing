# %%
# !pip install torch transformers yt-dlp openai-whisper pyannote.audio
from utils import *
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.1/172.1 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 25.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 38.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.0/811.0 kB 37.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 2. Use `yt-dlp` to download audio from video

# %%
download_audio("https://www.youtube.com/shorts/vd9GxG5Qn-k/")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/shorts/vd9GxG5Qn-k/
# [youtube] vd9GxG5Qn-k: Downloading webpage
# [youtube] vd9GxG5Qn-k: Downloading ios player API JSON
# [youtube] vd9GxG5Qn-k: Downloading mweb player API JSON
# [youtube] vd9GxG5Qn-k: Downloading player 28f14d97
# [youtube] vd9GxG5Qn-k: Downloading m3u8 information
# [info] vd9GxG5Qn-k: Downloading 1 format(s): 251
# [download] Destination: temp_audio.webm
# [download] 100% of  479.22KiB in 00:00:00 at 1.68MiB/s
# [ExtractAudio] Destination: temp_audio.wav
# Deleting original file temp_audio.webm (pass -k to keep)
# 'temp_audio.wav'

# %% [markdown]
# ## 3. Use Whisper to determine the language spoken

# %%
detected_lang = detect_audio_language("temp_audio.wav")
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:05<00:00, 27.5MiB/s]
# ...

# %% [markdown]
# ## 4. Use Speaker diarization + Openai Whisper
#
#    Hope to be like this
#
# - second 1-3, speaker 1, "Hello Everybody"
# - second 5-9, speaker 2, "Today we are going to introduce"
# - second 10-14, speaker 1(again), "The news is"

# %%
diarization = get_diarization("temp_audio.wav")
segments = transcribe_segments("temp_audio.wav", diarization)
# Out:
# config.yaml:   0%|          | 0.00/469 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/5.91M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/399 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/26.6M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/221 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/models/blocks/pooling.py:104: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at ../aten/src/ATen/native/ReduceOps.cpp:1823.)
#   std = sequences.std(dim=-1, correction=1)
# ...

# %% [markdown]
# ## 5. Translate the languages into Russian with Helsinki-NLP

# %%
target_lang='ru'
translated_segments = translate(detected_lang, target_lang, segments)
# Out:
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/803k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.60M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/307M [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## 6. Text to speech with different speakers
#    Make sure the generated audio track is the same length as original audio, if not, pad with silence.

# %%
print(translated_segments)
print(target_lang)
# Out:
# [{'start': 0.03096875, 'end': 4.82346875, 'speaker': 'SPEAKER_00', 'text': 'Как бы вы определили AGI и как, по-вашему, вы узнаете?'}, {'start': 4.82346875, 'end': 32.16096875, 'speaker': 'SPEAKER_01', 'text': 'Я думаю, что в этом есть много веских определений, но для меня AGI - это в основном эквивалент среднего человека, которого вы могли бы нанять как коллегу. И тогда они могли бы сказать, сделать все, что вы были бы счастливы, если бы вы сделали дистанционный коллегу, прямо за компьютером, который включает, знаете, обучение как стать доктором, как стать очень компетентным кодировщиком. Есть много вещей, в которых средний человек способен преуспеть. И я думаю, что один из навыков AGI не является какой-то конкретной вехой, а мета-навык обучения, чтобы вычислить вещи, и что он может принять решение о том, что хорошо в чем вы нуждаетесь.'}]
# ru

# %%
generate_tts_silero(translated_segments, target_lang)
# Out:
#   0%|          | 0.00/38.2M [00:00<?, ?B/s]
#   0%|          | 128k/38.2M [00:00<02:22, 281kB/s]
#   1%|          | 256k/38.2M [00:00<01:27, 453kB/s]
#   1%|▏         | 512k/38.2M [00:00<00:48, 822kB/s]
#   2%|▏         | 896k/38.2M [00:00<00:29, 1.33MB/s]
#   5%|▍         | 1.75M/38.2M [00:01<00:14, 2.67MB/s]
#   9%|▉         | 3.50M/38.2M [00:01<00:06, 5.23MB/s]
#  18%|█▊        | 6.88M/38.2M [00:01<00:03, 10.2MB/s]
#  26%|██▌       | 9.88M/38.2M [00:01<00:02, 12.8MB/s]
#  34%|███▍      | 13.0M/38.2M [00:01<00:01, 14.9MB/s]
#  42%|████▏     | 16.0M/38.2M [00:01<00:01, 15.5MB/s]
#  50%|████▉     | 19.0M/38.2M [00:02<00:01, 16.5MB/s]
#  58%|█████▊    | 22.0M/38.2M [00:02<00:00, 17.5MB/s]
#  66%|██████▌   | 25.1M/38.2M [00:02<00:00, 18.1MB/s]
#  74%|███████▎  | 28.1M/38.2M [00:02<00:00, 18.2MB/s]
#  81%|████████▏ | 31.1M/38.2M [00:02<00:00, 18.3MB/s]
#  89%|████████▉ | 34.1M/38.2M [00:02<00:00, 18.5MB/s]
# 100%|██████████| 38.2M/38.2M [00:03<00:00, 12.7MB/s]

# %%
# !lss
# Out:
# output_audio.wav  sample_data  temp_audio.wav  temp_segment.wav
